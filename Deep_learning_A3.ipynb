# %%
# !pip install yfinance
# !pip install pmdarima
# Out:
# Requirement already satisfied: yfinance in c:\users\viral panchal\anaconda3\lib\site-packages (0.2.50)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\viral panchal\anaconda3\lib\site-packages (from yfinance) (1.5.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\viral panchal\anaconda3\lib\site-packages (from yfinance) (1.24.3)
# Requirement already satisfied: requests>=2.31 in c:\users\viral panchal\anaconda3\lib\site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\viral panchal\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\viral panchal\anaconda3\lib\site-packages (from yfinance) (4.9.3)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\viral panchal\anaconda3\lib\site-packages (from yfinance) (3.10.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\viral panchal\anaconda3\lib\site-packages (from yfinance) (2023.3.post1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\viral panchal\anaconda3\lib\site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\viral panchal\anaconda3\lib\site-packages (from yfinance) (3.17.8)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\viral panchal\anaconda3\lib\site-packages (from yfinance) (4.12.2)
# Requirement already satisfied: html5lib>=1.1 in c:\users\viral panchal\anaconda3\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\viral panchal\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4)
# Requirement already satisfied: six>=1.9 in c:\users\viral panchal\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\viral panchal\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\viral panchal\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\viral panchal\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\viral panchal\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\viral panchal\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\viral panchal\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2024.8.30)
# Requirement already satisfied: pmdarima in c:\users\viral panchal\anaconda3\lib\site-packages (2.0.4)
# Requirement already satisfied: joblib>=0.11 in c:\users\viral panchal\anaconda3\lib\site-packages (from pmdarima) (1.2.0)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\viral panchal\anaconda3\lib\site-packages (from pmdarima) (3.0.11)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\viral panchal\anaconda3\lib\site-packages (from pmdarima) (1.24.3)
# Requirement already satisfied: pandas>=0.19 in c:\users\viral panchal\anaconda3\lib\site-packages (from pmdarima) (1.5.3)
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\viral panchal\anaconda3\lib\site-packages (from pmdarima) (1.3.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\viral panchal\anaconda3\lib\site-packages (from pmdarima) (1.12.0)
# Requirement already satisfied: statsmodels>=0.13.2 in c:\users\viral panchal\anaconda3\lib\site-packages (from pmdarima) (0.14.0)
# Requirement already satisfied: urllib3 in c:\users\viral panchal\anaconda3\lib\site-packages (from pmdarima) (1.26.16)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\viral panchal\anaconda3\lib\site-packages (from pmdarima) (68.0.0)
# Requirement already satisfied: packaging>=17.1 in c:\users\viral panchal\anaconda3\lib\site-packages (from pmdarima) (23.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\viral panchal\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\viral panchal\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2023.3.post1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\viral panchal\anaconda3\lib\site-packages (from scikit-learn>=0.22->pmdarima) (2.2.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\viral panchal\anaconda3\lib\site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.3)
# Requirement already satisfied: six in c:\users\viral panchal\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels>=0.13.2->pmdarima) (1.16.0)

# %%
import os
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
from pylab import rcParams
rcParams['figure.figsize'] = 10, 6
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima.model import ARIMA
from pmdarima.arima import auto_arima

from sklearn.metrics import mean_squared_error, mean_absolute_error
import math
import yfinance as yf

# %%
def get_stock_data(ticker, start_date, end_date):
    stock_data = yf.download(ticker,start=start_date,end=end_date)
    return stock_data

# %%
ticker_symbol = 'AAPL'
start_date = "2010-01-01"
end_date = "2023-01-01"

# %%
stock_data = get_stock_data(ticker_symbol, start_date, end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
stock_data.head()
# Out:
# Price      Adj Close     Close      High       Low      Open     Volume
# Ticker          AAPL      AAPL      AAPL      AAPL      AAPL       AAPL
# Date
# 2010-01-04  6.447412  7.643214  7.660714  7.585000  7.622500  493729600
# 2010-01-05  6.458558  7.656429  7.699643  7.616071  7.664286  601904800
# 2010-01-06  6.355828  7.534643  7.686786  7.526786  7.656429  552160000
# 2010-01-07  6.344077  7.520714  7.571429  7.466071  7.562500  477131200
# 2010-01-08  6.386254  7.570714  7.571429  7.466429  7.510714  447610800

# %%
csv_filename = 'commbank_stock_data.csv'
stock_data.to_csv(csv_filename)

# %%
stock_data['Percentage'] = stock_data['Adj Close'].pct_change() * 100


stock_data.head()
# Out:
# Price      Adj Close     Close      High       Low      Open     Volume  \
# Ticker          AAPL      AAPL      AAPL      AAPL      AAPL       AAPL
# Date
# 2010-01-04  6.447412  7.643214  7.660714  7.585000  7.622500  493729600
# 2010-01-05  6.458558  7.656429  7.699643  7.616071  7.664286  601904800
# 2010-01-06  6.355828  7.534643  7.686786  7.526786  7.656429  552160000
# 2010-01-07  6.344077  7.520714  7.571429  7.466071  7.562500  477131200
# 2010-01-08  6.386254  7.570714  7.571429  7.466429  7.510714  447610800
#
# Price      Percentage
# Ticker
# Date
# 2010-01-04        NaN
# 2010-01-05   0.172884
# 2010-01-06  -1.590607
# 2010-01-07  -0.184888
# 2010-01-08   0.664836

# %%
plt.figure(figsize=(10,6))
plt.grid(True)
plt.xlabel('Date')
plt.ylabel('Close Prices')
plt.plot(stock_data['Adj Close'])
plt.title(f'{ticker_symbol} closing price')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.grid(True)
plt.xlabel('Date')
plt.ylabel('Percentage Change')
plt.plot(stock_data['Percentage'])
plt.title(f'{ticker_symbol} Percentage')
plt.show()

# %%
stock_data["Adj Close"].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
stock_data["Percentage"].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df_close = stock_data["Close"]

# %%
df_percentage =stock_data["Percentage"].dropna()

# %%
#Test for staionarity
def test_stationarity(timeseries):
    #Determing rolling statistics
    rolmean = timeseries.rolling(12).mean()
    rolstd = timeseries.rolling(12).std()
    #Plot rolling statistics:
    plt.plot(timeseries, color='blue',label='Original')
    plt.plot(rolmean, color='red', label='Rolling Mean')
    plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean and Standard Deviation')
    plt.show(block=False)
    
    print("Results of dickey fuller test")
    adft = adfuller(timeseries,autolag='AIC')
    # output for dft will give us without defining what the values are.
    #hence we manually write what values does it explains using a for loop
    output = pd.Series(adft[0:4],index=['Test Statistics','p-value','No. of lags used','Number of observations used'])
    for key,values in adft[4].items():
        output['critical value (%s)'%key] =  values
    print(output)
    
test_stationarity(df_close)
test_stationarity(df_percentage)
# Out:
# Results of dickey fuller test
# Test Statistics                  -0.287761
# p-value                           0.927220
# No. of lags used                 22.000000
# Number of observations used    3249.000000
# critical value (1%)              -3.432364
# critical value (5%)              -2.862430
# critical value (10%)             -2.567244
# dtype: float64
# Results of dickey fuller test
# Test Statistics               -1.170007e+01
# p-value                        1.576414e-21
# No. of lags used               2.100000e+01
# Number of observations used    3.249000e+03
# critical value (1%)           -3.432364e+00
# critical value (5%)           -2.862430e+00
# critical value (10%)          -2.567244e+00
# dtype: float64

# %%
result = seasonal_decompose(df_close, model='multiplicative', period = 365)
fig = plt.figure()  
fig = result.plot()  
fig.set_size_inches(16, 9)

# %%
result = seasonal_decompose(df_percentage, model='additive', period = 30)
fig = plt.figure()  
fig = result.plot()  
fig.set_size_inches(16, 9)

# %%
#if not stationary then eliminate trend
#Eliminate trend
from pylab import rcParams
rcParams['figure.figsize'] = 10, 6
df_log = np.log(df_close)
moving_avg = df_log.rolling(12).mean()
std_dev = df_log.rolling(12).std()
plt.legend(loc='best')
plt.title('Moving Average')
plt.plot(std_dev, color ="black", label = "Standard Deviation")
plt.plot(moving_avg, color="red", label = "Mean")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
from pmdarima.arima.utils import ndiffs
print(ndiffs(df_log))
df_close_diff = df_log
moving_avg = df_close_diff.rolling(12).mean()
std_dev = df_close_diff.rolling(12).std()
plt.legend(loc='best')
plt.title('Moving Average')
plt.plot(std_dev, color ="black", label = "Standard Deviation")
plt.plot(moving_avg, color="red", label = "Mean")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 1

# %%
df_close_diff = df_log.diff()
moving_avg = df_close_diff.rolling(12).mean()
std_dev = df_close_diff.rolling(12).std()
plt.legend(loc='best')
plt.title('Moving Average')
plt.plot(std_dev, color ="black", label = "Standard Deviation")
plt.plot(moving_avg, color="red", label = "Mean")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#split data into train and training set

train_data, test_data = df_log[3:int(len(df_log)*0.95)], df_log[int(len(df_log)*0.90):]

plt.figure(figsize=(10,6))
plt.grid(True)
plt.xlabel('Dates')
plt.ylabel('Closing Prices')
plt.plot(train_data, 'green', label='Train data')
plt.plot(test_data, 'blue', label='Test data')
plt.legend()

# %%
df_percentage = df_percentage.dropna()
train_data_per, test_data_per = df_percentage[3:int(len(df_percentage)*0.90)], df_percentage[int(len(df_percentage)*0.90):]

plt.figure(figsize=(10,6))
plt.grid(True)
plt.xlabel('Dates')
plt.ylabel('Closing Prices')
plt.plot(train_data_per, 'green', label='Train data')
plt.plot(test_data_per, 'blue', label='Test data')
plt.legend()

# %%
model_autoARIMA = auto_arima(train_data, start_p=0, start_q=0,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=3, max_q=3, # maximum p and q
                      m=1,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      start_P=0, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)
print(model_autoARIMA.summary())
model_autoARIMA.plot_diagnostics(figsize=(15,8))
plt.show()
print()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-16202.055, Time=0.23 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-16207.192, Time=0.23 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-16207.099, Time=0.22 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-16194.653, Time=0.10 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=-16205.333, Time=0.46 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-16205.876, Time=0.37 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=-16203.305, Time=0.79 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=-16198.879, Time=0.09 sec
#
# Best model:  ARIMA(1,1,0)(0,0,0)[0] intercept
# Total fit time: 2.504 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 3105
# Model:               SARIMAX(1, 1, 0)   Log Likelihood                8106.596
# Date:                Sat, 07 Dec 2024   AIC                         -16207.192
# Time:                        22:26:03   BIC                         -16189.070
# Sample:                             0   HQIC                        -16200.685
#                                - 3105
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0010      0.000      3.176      0.001       0.000       0.002
# ar.L1         -0.0479      0.012     -4.105      0.000      -0.071      -0.025
# sigma2         0.0003   4.37e-06     72.186      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              4090.84
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.40   Skew:                            -0.31
# Prob(H) (two-sided):                  0.00   Kurtosis:                         8.59
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
model_autoARIMA_per = auto_arima(train_data_per, start_p=2, start_q=2,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=3, max_q=3,  # maximum p and q
                      m=1,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      start_P=1, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)
print(model_autoARIMA.summary())
model_autoARIMA.plot_diagnostics(figsize=(15,8))
plt.show()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=11694.790, Time=0.91 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=11730.265, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=11725.172, Time=0.06 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=11725.389, Time=0.08 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=11727.562, Time=0.28 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=11727.563, Time=0.30 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=11696.473, Time=1.22 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=11696.438, Time=1.11 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=11725.571, Time=0.20 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=11728.179, Time=0.38 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=11728.419, Time=0.57 sec
#  ARIMA(3,0,3)(0,0,0)[0]             : AIC=11697.852, Time=1.57 sec
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=11715.609, Time=1.40 sec
#
# Best model:  ARIMA(2,0,2)(0,0,0)[0]
# Total fit time: 8.107 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 3105
# Model:               SARIMAX(1, 1, 0)   Log Likelihood                8106.596
# Date:                Sat, 07 Dec 2024   AIC                         -16207.192
# Time:                        22:26:11   BIC                         -16189.070
# Sample:                             0   HQIC                        -16200.685
#                                - 3105
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0010      0.000      3.176      0.001       0.000       0.002
# ar.L1         -0.0479      0.012     -4.105      0.000      -0.071      -0.025
# sigma2         0.0003   4.37e-06     72.186      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              4090.84
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.40   Skew:                            -0.31
# Prob(H) (two-sided):                  0.00   Kurtosis:                         8.59
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
model = ARIMA(train_data, order=(3,0,1))  
fitted = model.fit()  
print(fitted.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   AAPL   No. Observations:                 3105
# Model:                 ARIMA(3, 0, 1)   Log Likelihood                8099.900
# Date:                Sat, 07 Dec 2024   AIC                         -16187.800
# Time:                        22:26:12   BIC                         -16151.556
# Sample:                             0   HQIC                        -16174.786
#                                - 3105
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.4899      0.964      3.621      0.000       1.601       5.379
# ar.L1          0.6454      0.986      0.654      0.513      -1.288       2.578
# ar.L2          0.3507      0.937      0.374      0.708      -1.486       2.188
# ar.L3          0.0036      0.050      0.072      0.943      -0.095       0.102
# ma.L1          0.3103      0.982      0.316      0.752      -1.615       2.235
# sigma2         0.0003   4.41e-06     71.869      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.03   Jarque-Bera (JB):              4109.90
# Prob(Q):                              0.86   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.40   Skew:                            -0.29
# Prob(H) (two-sided):                  0.00   Kurtosis:                         8.61
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
model = ARIMA(train_data_per, order=(3,0,1))  
fitted = model.fit()  
print(fitted.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:             Percentage   No. Observations:                 2940
# Model:                 ARIMA(3, 0, 1)   Log Likelihood               -5851.249
# Date:                Sat, 07 Dec 2024   AIC                          11714.497
# Time:                        22:26:13   BIC                          11750.414
# Sample:                             0   HQIC                         11727.430
#                                - 2940
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1227      0.032      3.824      0.000       0.060       0.186
# ar.L1         -0.1588      0.442     -0.359      0.720      -1.026       0.708
# ar.L2          0.0033      0.026      0.124      0.901      -0.048       0.055
# ar.L3         -0.0296      0.016     -1.857      0.063      -0.061       0.002
# ma.L1          0.1057      0.439      0.241      0.810      -0.755       0.966
# sigma2         3.1348      0.045     69.856      0.000       3.047       3.223
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              3865.83
# Prob(Q):                              1.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.37   Skew:                            -0.13
# Prob(H) (two-sided):                  0.00   Kurtosis:                         8.61
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
from statsmodels.tsa.stattools import acf, pacf
import statsmodels.tsa.api as smt
import statsmodels as sm
# define a function to plot ACF and PACF to determine p and q
def tsplot(y, lags=None, figsize=(12, 7), style='bmh'):
    if not isinstance(y, pd.Series):
        y = pd.Series(y)
        
    with plt.style.context(style):    
        fig = plt.figure(figsize=figsize)
        layout = (2, 2)
        ts_ax = plt.subplot2grid(layout, (0, 0), colspan=2)
        acf_ax = plt.subplot2grid(layout, (1, 0))
        pacf_ax = plt.subplot2grid(layout, (1, 1))
        
        y.plot(ax=ts_ax)
        p_value = sm.tsa.stattools.adfuller(y)[0]
        ts_ax.set_title(f'Time Series Analysis Plots\n Dickey-Fuller: p={0:.5f}'.format(p_value))
        smt.graphics.plot_acf(y, lags=lags, ax=acf_ax)
        smt.graphics.plot_pacf(y, lags=lags, ax=pacf_ax)
        plt.tight_layout()

# %%
tsplot(train_data,lags=4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1872\4178378364.py in ?()
# ----> 1 tsplot(train_data,lags=4)
#
# ~\AppData\Local\Temp\ipykernel_1872\977126780.py in ?(y, lags, figsize, style)
#       5 def tsplot(y, lags=None, figsize=(12, 7), style='bmh'):
#       6     if not isinstance(y, pd.Series):
# ----> 7         y = pd.Series(y)
#       8
#       9     with plt.style.context(style):
#      10         fig = plt.figure(figsize=figsize)
#
# ~\anaconda3\Lib\site-packages\pandas\core\series.py in ?(self, data, index, dtype, name, copy, fastpath)
#     382         else:
#     383
#     384             name = ibase.maybe_extract_name(name, data, type(self))
#     385
# --> 386             if is_empty_data(data) and dtype is None:
#     387                 # gh-17261
#     388                 warnings.warn(
#     389                     "The default dtype for empty Series will be 'object' instead "
#
# ~\anaconda3\Lib\site-packages\pandas\core\construction.py in ?(data)
#     873     bool
#     874     """
#     875     is_none = data is None
#     876     is_list_like_without_dtype = is_list_like(data) and not hasattr(data, "dtype")
# --> 877     is_simple_empty = is_list_like_without_dtype and not data
#     878     return is_none or is_simple_empty
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self)
#    1525     @final
#    1526     def __nonzero__(self) -> NoReturn:
# -> 1527         raise ValueError(
#    1528             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530         )
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
tsplot(train_data_per,lags=4)

# %%
model = ARIMA(train_data,order = (3,0,1))
model_fit = model.fit()
print(model_fit.summary())

# %%
# in-sample rolling forecast
# split the training set removing the last 2 months 

size = len(test_data)

history = [x for x in train_data] ## list

predictions = []

for t in range(size):
    
    model = ARIMA(history, order=(1,1,0))
    model_fit = model.fit()
    
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(float(yhat))
    
    obs = test_data[t]
    history.append(obs)

# %%
model = ARIMA(train_data,order=(0,1,1))
model_fit = model.fit()
residuals_test = train_data - model_fit.fittedvalues
residuals_test = residuals_test.reset_index()
test =  model_fit.fittedvalues.reset_index()
residuals_test["Forecast Values"] = test[0]
residuals_test = residuals_test.rename(columns={0:'residual'})

# %%
forecasted_values =  pd.DataFrame({
    
    'Date' : test_data.index,
    'Actual Values' : test_data.values,
    'Forecast Values' : predictions
    
})
forecasted_values.head(10)

# %%
fig, ax = plt.subplots(figsize = (12,9))

plt.plot(train_data.index, train_data.values, label = 'In-sample Test Set(Actual Values)')
plt.plot(test_data.index, test_data.values, label = 'In-sample Test Set(Actual Values)')
plt.plot(forecasted_values.Date, forecasted_values['Forecast Values'], label='Forecasted')
plt.title('Test Set vs. Forcasted Values')

plt.legend()
plt.grid(True)
plt.show()

# %%
forecasted_values["residual"] = forecasted_values["Actual Values"] - forecasted_values["Forecast Values"]
forecasted_values.head()

# %%
mse = np.mean(((forecasted_values["residual"]))**2)
mae = np.mean(np.abs(forecasted_values["residual"]))
print(mse,mae)
# Out:
# 0.0004484811172702314 0.016157796965991497

# %%
from keras.layers import LSTM, Dense, Dropout
from keras.models import Sequential

def train_lstm(x_train, y_train, epochs=100, batch_size=32, validation_split=0.1):
    model = Sequential()
    model.add(LSTM(50, activation='relu', input_shape=(x_train.shape[1], 1), return_sequences=True))
    model.add(Dropout(0.2))  # Dropout after the first LSTM layer
    model.add(LSTM(50, activation='relu', return_sequences=False))
    model.add(Dropout(0.2))  # Dropout after the second LSTM layer
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mae', metrics=["mae"])

    model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size, verbose=1, validation_split=validation_split)

    return model

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense


x_train = residuals_test["Forecast Values"].values.reshape(-1, 1, 1)
y_train = residuals_test["residual"].values
model_lstm = train_lstm(x_train,y_train,100)
# Out:
# Epoch 1/100
# 88/88 [==============================] - 4s 10ms/step - loss: 0.0135 - mae: 0.0135 - val_loss: 0.0134 - val_mae: 0.0134
# Epoch 2/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.0133 - mae: 0.0133 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 3/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0129 - val_mae: 0.0129
# Epoch 4/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 5/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0132 - val_mae: 0.0132
# Epoch 6/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0133 - mae: 0.0133 - val_loss: 0.0130 - val_mae: 0.0130
# Epoch 7/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0129 - val_mae: 0.0129
# Epoch 8/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 9/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0129 - val_mae: 0.0129
# Epoch 10/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 11/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0129 - val_mae: 0.0129
# Epoch 12/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 13/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0129 - val_mae: 0.0129
# Epoch 14/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0129 - val_mae: 0.0129
# Epoch 15/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0129 - val_mae: 0.0129
# Epoch 16/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 17/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 18/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 19/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 20/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 21/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0129 - val_mae: 0.0129
# Epoch 22/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 23/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 24/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 25/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0129 - val_mae: 0.0129
# Epoch 26/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 27/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0129 - val_mae: 0.0129
# Epoch 28/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 29/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0129 - val_mae: 0.0129
# Epoch 30/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 31/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0130 - val_mae: 0.0130
# Epoch 32/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 33/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0129 - val_mae: 0.0129
# Epoch 34/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0129 - val_mae: 0.0129
# Epoch 35/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 36/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 37/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 38/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0129 - val_mae: 0.0129
# Epoch 39/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 40/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0129 - val_mae: 0.0129
# Epoch 41/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 42/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0133 - mae: 0.0133 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 43/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 44/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 45/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0129 - val_mae: 0.0129
# Epoch 46/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0129 - val_mae: 0.0129
# Epoch 47/100
# 88/88 [==============================] - 1s 6ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0132 - val_mae: 0.0132
# Epoch 48/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 49/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 50/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 51/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0129 - val_mae: 0.0129
# Epoch 52/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 53/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 54/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 55/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0130 - val_mae: 0.0130
# Epoch 56/100
# 88/88 [==============================] - 1s 6ms/step - loss: 0.0133 - mae: 0.0133 - val_loss: 0.0129 - val_mae: 0.0129
# Epoch 57/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0129 - val_mae: 0.0129
# Epoch 58/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0129 - val_mae: 0.0129
# Epoch 59/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 60/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 61/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0133 - mae: 0.0133 - val_loss: 0.0129 - val_mae: 0.0129
# Epoch 62/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0130 - val_mae: 0.0130
# Epoch 63/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 64/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0129 - val_mae: 0.0129
# Epoch 65/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 66/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 67/100
# 88/88 [==============================] - 1s 6ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 68/100
# 88/88 [==============================] - 1s 6ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 69/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0129 - val_mae: 0.0129
# Epoch 70/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0129 - val_mae: 0.0129
# Epoch 71/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 72/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0129 - val_mae: 0.0129
# Epoch 73/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 74/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0129 - val_mae: 0.0129
# Epoch 75/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0129 - val_mae: 0.0129
# Epoch 76/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 77/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 78/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 79/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 80/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 81/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0130 - val_mae: 0.0130
# Epoch 82/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0129 - val_mae: 0.0129
# Epoch 83/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 84/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 85/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 86/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 87/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 88/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 89/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0130 - val_mae: 0.0130
# Epoch 90/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 91/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 92/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 93/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0129 - val_mae: 0.0129
# Epoch 94/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0129 - val_mae: 0.0129
# Epoch 95/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 96/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 97/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 98/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128
# Epoch 99/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0129 - val_mae: 0.0129
# Epoch 100/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0128 - val_mae: 0.0128

# %%
from keras.utils import plot_model

plot_model(model_lstm, to_file='lstm_model.png', show_shapes=True, show_layer_names=True)

# %%
x_test = forecasted_values["Forecast Values"].values.reshape(-1, 1, 1)
y_test = forecasted_values["residual"].values
y_actual = forecasted_values["Actual Values"].values
# Make predictions
y_pred = model_lstm.predict(x_test)
# Evaluate performance
mse1 = np.mean((y_actual - (x_test))**2)
mae1 = np.mean(np.abs(y_actual - (x_test)))

mse = np.mean((y_actual - (x_test + y_pred.squeeze()))**2)
mae = np.mean(np.abs(y_actual - (x_test + y_pred.squeeze())))

print(mse,mae,mse1,mae1)
# Out:
# 11/11 [==============================] - 0s 2ms/step
# 0.013781621485899441 0.09524262019920318 0.013781725456483008 0.09524291606008288

# %%
size = len(test_data)

history = [x for x in train_data] ## list
predictions = []


    
model = ARIMA(history, order=(0,1,1))
model_fit = model.fit()
    
output = model_fit.forecast(size)

# %%
fig, ax = plt.subplots(figsize = (12,9))
plt.plot(train_data.index, np.exp(train_data.values), label = 'In-sample Test Set(Actual Values)')

plt.plot(test_data.index, np.exp(test_data.values), label = 'In-sample Test Set(Actual Values)')
plt.plot(forecasted_values.Date, np.exp(forecasted_values['Forecast Values']), label='Forecasted')
plt.title('Test Set vs. Forcasted Values')

plt.legend()
plt.grid(True)
plt.show()
